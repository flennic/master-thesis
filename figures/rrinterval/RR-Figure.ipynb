# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
path = "/home/flennic/Downloads/out.txt"
# %matplotlib inline
plt.rcParams['figure.dpi'] = 160
color = sns.color_palette("viridis", 10)[5]

# %%
df = pd.read_csv(path, sep="\t")
df.columns = ["Index", "Signal"]
df
# Out:
#        Index  Signal
# 0          1    2072
# 1          2    2070
# 2          3    2072
# 3          4    2072
# 4          5    2072
# ...      ...     ...
# 43075  43076    2075
# 43076  43077    2076
# 43077  43078    2075
# 43078  43079    2075
# 43079  43080    2075
#
# [43080 rows x 2 columns]

# %%
delta_t = 1/720
#[mult * delta_t for mult in range(2000)]

# %%
sns.lineplot([mult * delta_t for mult in range(2000)], -df["Signal"][10_000:12_000], color=color);
plt.ylabel('Voltage in µV');
plt.xlabel('Time in Seconds');
plt.title('RR Interval');

# %%
sns.lineplot(df["Index"][10_000:12_000], -df["Signal"][10_000:12_000], color=color);
plt.ylabel('Voltage');
plt.xlabel('ContractionNo');
#plt.title('Time Series for: {}{}, started at {} | First 100'.format(recordings[idx]["Gender"], recordings[idx]["AgeDecade"], recordings[idx]["RecordingStartTime"]));
